# %% [markdown]
# Webscaping notes made by Jedlueng, 21 January 2021

# %%
#Request to get in the webpage 
import requests 


url = 'https://www.londonstockexchange.com/indices?tab=ftse-indices'

html = requests.get(url)


#Check status 
html.status_code

#200 equal great

# %% [markdown]
# Use beautiful soup to make HTML easier to access

# %%
from bs4 import BeautifulSoup
url_html = html.text
url_content = BeautifulSoup(url_html, 'html.parser')

# %% [markdown]
# Find method for bs4

# %%
#Put in html tag in the parameter
print(url_content.prettify())
#url_content.find()
#url_content.findAll()
# Out:
# <!DOCTYPE html>
# <html lang="en">
#  <head>
#   <meta charset="utf-8"/>
#   <title>
#    All Indices | London Stock Exchange
#   </title>
#   <base href="/"/>
#   <meta content="width=device-width, initial-scale=1" name="viewport"/>
#   <meta content="1703499E93B0477E0BC3380E8DB64303" name="msvalidate.01"/>
#   <meta content="telephone=no" name="format-detection"/>
#   <link href="/favicon.ico" rel="icon" type="image/x-icon"/>
#   <link as="font" crossorigin="" href="/assets/fonts/subset-FSLola.woff2" rel="preload" type="font/woff2"/>
#   <link as="font" crossorigin="" href="/assets/fonts/subset-FSLola-ExtraBold.woff2" rel="preload" type="font/woff2"/>
#   <link as="font" crossorigin="" href="/assets/fonts/subset-FSLola-Bold.woff2" rel="preload" type="font/woff2"/>
#   <script>
#    var global = global || window;
#   </script>
#   <script src="https://cc.cdn.civiccomputing.com/9/cookieControl-9.x.min.js" type="text/javascript">
#   </script>
#   <script type="application/ld+json">
# ...

# %%
#Find contact info
#Find that section then find text
#Use function over funtion
email = soup.find(class_ = "contactinfo").find_all('a')[0].text
room = soup.find(class_ = "contactinfo").find_all('a')[2].text
